# %%
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import linear_model, preprocessing

# %%
data = pd.read_csv("./car/car.data")
data.head()
# Out:
#   buying  maint door persons lug_boot safety  class
# 0  vhigh  vhigh    2       2    small    low  unacc
# 1  vhigh  vhigh    2       2    small    med  unacc
# 2  vhigh  vhigh    2       2    small   high  unacc
# 3  vhigh  vhigh    2       2      med    low  unacc
# 4  vhigh  vhigh    2       2      med    med  unacc

# %%
# preprocessing the non-numerical data to numerical
le = preprocessing.LabelEncoder()
buying = le.fit_transform(list(data["buying"]))
maint = le.fit_transform(list(data["maint"]))
door = le.fit_transform(list(data["door"]))
persons = le.fit_transform(list(data["persons"]))
lug_boot = le.fit_transform(list(data["lug_boot"]))
safety = le.fit_transform(list(data["safety"]))
classs = le.fit_transform(list(data["class"]))

# %%
predict = 'class'

X = list(zip(buying,maint,door,persons,lug_boot,safety))
y = list(classs)

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
model = KNeighborsClassifier(n_neighbors=7)

model.fit(x_train, y_train)
acc = model.score(x_test, y_test)
print(acc)
# Out:
# 0.9421965317919075

# %%
predicted = model.predict(x_test)
names = ['unacc', 'acc', 'good', 'vgood']

for x in range(len(predicted)):
    print('Pred: {} Real: {} Data: {}'.format(predicted[x], y_test[x], x_test[x]))
# Out:
# Pred: 2 Real: 2 Data: (1, 2, 0, 0, 2, 0)
# Pred: 0 Real: 0 Data: (2, 0, 0, 1, 0, 0)
# Pred: 2 Real: 2 Data: (3, 1, 2, 0, 1, 0)
# Pred: 2 Real: 2 Data: (3, 1, 0, 1, 0, 1)
# Pred: 2 Real: 2 Data: (3, 1, 1, 0, 1, 2)
# Pred: 2 Real: 2 Data: (0, 0, 0, 1, 1, 2)
# Pred: 2 Real: 2 Data: (3, 0, 2, 2, 2, 0)
# Pred: 0 Real: 0 Data: (1, 3, 1, 2, 2, 0)
# Pred: 2 Real: 2 Data: (2, 0, 3, 0, 1, 1)
# Pred: 2 Real: 0 Data: (3, 1, 2, 1, 1, 2)
# Pred: 2 Real: 2 Data: (3, 0, 0, 0, 0, 1)
# Pred: 2 Real: 2 Data: (3, 2, 3, 0, 2, 1)
# Pred: 0 Real: 0 Data: (3, 1, 3, 1, 1, 0)
# Pred: 2 Real: 2 Data: (0, 0, 1, 0, 1, 0)
# Pred: 2 Real: 2 Data: (1, 2, 2, 0, 2, 0)
# Pred: 2 Real: 2 Data: (3, 2, 0, 0, 0, 0)
# Pred: 2 Real: 2 Data: (3, 2, 0, 0, 0, 2)
# Pred: 0 Real: 0 Data: (3, 1, 3, 2, 1, 0)
# Pred: 2 Real: 2 Data: (1, 1, 3, 1, 0, 1)
# Pred: 0 Real: 0 Data: (3, 1, 0, 1, 1, 0)
# Pred: 2 Real: 0 Data: (2, 3, 0, 1, 0, 2)
# Pred: 2 Real: 2 Data: (2, 2, 0, 0, 0, 1)
# Pred: 2 Real: 2 Data: (0, 0, 0, 2, 0, 1)
# Pred: 2 Real: 2 Data: (3, 0, 3, 1, 0, 0)
# Pred: 0 Real: 0 Data: (0, 2, 3, 2, 0, 0)
# Pred: 2 Real: 2 Data: (0, 3, 3, 2, 0, 1)
# Pred: 2 Real: 2 Data: (3, 2, 0, 0, 2, 0)
# Pred: 2 Real: 2 Data: (0, 1, 0, 2, 1, 1)
# Pred: 0 Real: 0 Data: (3, 1, 0, 1, 0, 0)
# Pred: 2 Real: 2 Data: (0, 3, 1, 0, 2, 0)
# Pred: 0 Real: 0 Data: (0, 2, 0, 2, 1, 0)
# Pred: 2 Real: 2 Data: (3, 2, 2, 0, 0, 1)
# Pred: 2 Real: 2 Data: (1, 1, 3, 0, 1, 0)
# Pred: 2 Real: 2 Data: (2, 1, 0, 1, 0, 1)
# Pred: 0 Real: 0 Data: (2, 1, 3, 1, 2, 2)
# Pred: 2 Real: 2 Data: (0, 0, 3, 0, 1, 0)
# Pred: 2 Real: 2 Data: (0, 2, 1, 0, 0, 2)
# Pred: 2 Real: 2 Data: (1, 3, 0, 0, 2, 0)
# Pred: 2 Real: 2 Data: (2, 2, 3, 0, 2, 0)
# Pred: 2 Real: 2 Data: (2, 3, 1, 0, 1, 1)
# Pred: 2 Real: 0 Data: (2, 1, 1, 2, 2, 2)
# Pred: 0 Real: 0 Data: (1, 3, 2, 1, 2, 0)
# Pred: 2 Real: 2 Data: (0, 0, 2, 0, 1, 0)
# Pred: 0 Real: 0 Data: (3, 2, 1, 2, 1, 0)
# Pred: 2 Real: 2 Data: (3, 2, 1, 0, 1, 0)
# Pred: 0 Real: 0 Data: (0, 1, 1, 2, 2, 0)
# Pred: 2 Real: 2 Data: (0, 1, 1, 1, 1, 1)
# Pred: 2 Real: 0 Data: (0, 0, 1, 2, 1, 2)
# Pred: 2 Real: 2 Data: (2, 1, 2, 2, 1, 1)
# Pred: 2 Real: 2 Data: (1, 3, 0, 0, 1, 0)
# Pred: 2 Real: 2 Data: (0, 3, 2, 1, 0, 2)
# Pred: 2 Real: 2 Data: (0, 3, 3, 2, 2, 1)
# Pred: 2 Real: 2 Data: (3, 3, 0, 0, 0, 0)
# Pred: 2 Real: 2 Data: (3, 3, 0, 0, 2, 1)
# Pred: 2 Real: 2 Data: (0, 1, 0, 1, 2, 1)
# Pred: 0 Real: 0 Data: (0, 1, 2, 1, 2, 0)
# Pred: 2 Real: 2 Data: (2, 3, 3, 1, 0, 1)
# Pred: 2 Real: 2 Data: (0, 0, 1, 0, 1, 1)
# Pred: 0 Real: 0 Data: (1, 3, 1, 2, 0, 0)
# Pred: 2 Real: 2 Data: (3, 3, 3, 0, 1, 1)
# Pred: 2 Real: 2 Data: (3, 1, 3, 0, 0, 1)
# Pred: 2 Real: 2 Data: (0, 2, 2, 0, 1, 0)
# Pred: 2 Real: 2 Data: (0, 0, 0, 1, 0, 1)
# Pred: 2 Real: 2 Data: (2, 0, 0, 0, 2, 1)
# Pred: 2 Real: 2 Data: (3, 3, 0, 0, 1, 2)
# Pred: 2 Real: 2 Data: (1, 3, 2, 2, 2, 2)
# Pred: 2 Real: 2 Data: (2, 2, 2, 2, 1, 1)
# Pred: 2 Real: 2 Data: (3, 2, 0, 1, 0, 1)
# Pred: 2 Real: 2 Data: (1, 3, 2, 1, 0, 1)
# Pred: 2 Real: 2 Data: (2, 2, 2, 0, 2, 2)
# Pred: 1 Real: 1 Data: (1, 1, 3, 1, 0, 2)
# Pred: 2 Real: 2 Data: (3, 3, 2, 1, 0, 1)
# Pred: 0 Real: 0 Data: (3, 2, 2, 2, 1, 2)
# Pred: 2 Real: 2 Data: (1, 2, 0, 0, 1, 2)
# Pred: 2 Real: 2 Data: (2, 3, 2, 2, 2, 2)
# Pred: 2 Real: 2 Data: (1, 3, 3, 2, 2, 1)
# Pred: 3 Real: 3 Data: (2, 1, 2, 1, 1, 0)
# Pred: 2 Real: 2 Data: (2, 2, 3, 0, 0, 2)
# Pred: 1 Real: 1 Data: (1, 2, 3, 1, 0, 2)
# Pred: 3 Real: 3 Data: (2, 2, 3, 1, 1, 0)
# Pred: 2 Real: 2 Data: (0, 0, 0, 0, 1, 0)
# Pred: 0 Real: 0 Data: (2, 0, 3, 1, 0, 0)
# Pred: 2 Real: 2 Data: (2, 0, 2, 1, 0, 1)
# Pred: 1 Real: 1 Data: (1, 1, 3, 2, 0, 2)
# Pred: 2 Real: 2 Data: (3, 2, 3, 0, 0, 1)
# Pred: 2 Real: 2 Data: (3, 0, 1, 0, 1, 0)
# Pred: 0 Real: 0 Data: (3, 1, 3, 2, 2, 0)
# Pred: 2 Real: 2 Data: (3, 3, 2, 1, 2, 0)
# Pred: 2 Real: 2 Data: (2, 2, 3, 1, 1, 1)
# Pred: 2 Real: 2 Data: (0, 3, 2, 1, 2, 0)
# Pred: 2 Real: 2 Data: (2, 3, 3, 1, 2, 2)
# Pred: 2 Real: 2 Data: (2, 1, 0, 2, 2, 0)
# Pred: 0 Real: 0 Data: (1, 0, 3, 1, 0, 2)
# Pred: 2 Real: 2 Data: (3, 2, 1, 0, 2, 0)
# Pred: 2 Real: 2 Data: (3, 3, 0, 2, 2, 0)
# Pred: 0 Real: 0 Data: (3, 2, 1, 1, 2, 0)
# Pred: 0 Real: 0 Data: (2, 3, 1, 1, 1, 0)
# Pred: 2 Real: 2 Data: (1, 2, 1, 2, 2, 1)
# Pred: 2 Real: 2 Data: (1, 1, 2, 0, 0, 1)
# Pred: 2 Real: 2 Data: (1, 0, 2, 2, 1, 1)
# Pred: 2 Real: 2 Data: (0, 0, 2, 0, 2, 0)
# Pred: 2 Real: 2 Data: (3, 0, 2, 2, 0, 0)
# Pred: 2 Real: 2 Data: (2, 0, 3, 0, 2, 1)
# Pred: 2 Real: 2 Data: (2, 0, 3, 0, 0, 1)
# Pred: 2 Real: 2 Data: (2, 3, 0, 0, 2, 2)
# Pred: 2 Real: 2 Data: (0, 0, 0, 2, 1, 1)
# Pred: 2 Real: 2 Data: (3, 2, 3, 2, 2, 2)
# Pred: 2 Real: 2 Data: (1, 3, 3, 1, 1, 1)
# Pred: 0 Real: 0 Data: (1, 2, 1, 2, 2, 2)
# Pred: 0 Real: 0 Data: (1, 3, 2, 2, 1, 2)
# Pred: 2 Real: 2 Data: (1, 0, 0, 0, 1, 1)
# Pred: 2 Real: 2 Data: (0, 3, 3, 2, 1, 1)
# Pred: 2 Real: 2 Data: (0, 2, 1, 2, 2, 1)
# Pred: 2 Real: 2 Data: (1, 3, 2, 0, 0, 0)
# Pred: 2 Real: 2 Data: (3, 0, 3, 0, 0, 0)
# Pred: 3 Real: 3 Data: (1, 0, 2, 2, 1, 0)
# Pred: 1 Real: 1 Data: (1, 1, 1, 1, 1, 0)
# Pred: 2 Real: 2 Data: (2, 1, 1, 0, 2, 1)
# Pred: 2 Real: 2 Data: (2, 3, 0, 0, 0, 1)
# Pred: 2 Real: 2 Data: (0, 0, 3, 1, 1, 1)
# Pred: 2 Real: 2 Data: (3, 1, 0, 1, 1, 1)
# Pred: 1 Real: 1 Data: (1, 2, 0, 1, 2, 0)
# Pred: 2 Real: 2 Data: (0, 1, 3, 0, 1, 2)
# Pred: 0 Real: 0 Data: (0, 0, 3, 2, 2, 0)
# Pred: 1 Real: 1 Data: (2, 1, 1, 1, 2, 0)
# Pred: 0 Real: 0 Data: (3, 1, 1, 2, 0, 2)
# Pred: 2 Real: 2 Data: (1, 0, 0, 2, 2, 0)
# Pred: 2 Real: 2 Data: (0, 1, 1, 0, 0, 0)
# Pred: 0 Real: 3 Data: (1, 0, 0, 2, 0, 0)
# Pred: 2 Real: 2 Data: (0, 1, 1, 1, 2, 1)
# Pred: 2 Real: 2 Data: (3, 0, 0, 2, 0, 2)
# Pred: 2 Real: 2 Data: (0, 3, 1, 0, 1, 1)
# Pred: 0 Real: 0 Data: (3, 2, 3, 2, 0, 0)
# Pred: 2 Real: 2 Data: (3, 0, 0, 1, 1, 1)
# Pred: 2 Real: 2 Data: (0, 3, 3, 0, 0, 2)
# Pred: 2 Real: 2 Data: (2, 2, 1, 0, 0, 1)
# Pred: 0 Real: 1 Data: (2, 1, 1, 2, 1, 2)
# Pred: 0 Real: 0 Data: (2, 2, 3, 2, 2, 2)
# Pred: 2 Real: 2 Data: (2, 3, 0, 2, 2, 1)
# Pred: 2 Real: 2 Data: (1, 1, 2, 0, 1, 0)
# Pred: 3 Real: 3 Data: (2, 1, 2, 1, 0, 0)
# Pred: 0 Real: 0 Data: (3, 1, 3, 2, 0, 2)
# Pred: 1 Real: 1 Data: (1, 2, 2, 1, 2, 0)
# Pred: 0 Real: 1 Data: (1, 2, 1, 1, 1, 0)
# Pred: 3 Real: 3 Data: (2, 1, 0, 2, 0, 0)
# Pred: 0 Real: 0 Data: (2, 1, 2, 2, 2, 2)
# Pred: 2 Real: 2 Data: (0, 2, 1, 0, 0, 0)
# Pred: 0 Real: 0 Data: (0, 1, 0, 1, 0, 0)
# Pred: 0 Real: 1 Data: (2, 1, 1, 1, 1, 0)
# Pred: 0 Real: 0 Data: (2, 0, 3, 2, 1, 0)
# Pred: 2 Real: 2 Data: (3, 0, 3, 2, 1, 2)
# Pred: 0 Real: 0 Data: (2, 0, 1, 2, 1, 0)
# Pred: 2 Real: 0 Data: (2, 2, 0, 1, 2, 2)
# Pred: 2 Real: 2 Data: (3, 0, 0, 2, 2, 0)
# Pred: 2 Real: 2 Data: (0, 3, 0, 2, 2, 0)
# Pred: 2 Real: 2 Data: (3, 0, 0, 2, 0, 1)
# Pred: 0 Real: 0 Data: (3, 1, 1, 2, 1, 0)
# Pred: 0 Real: 0 Data: (0, 2, 2, 2, 1, 2)
# Pred: 2 Real: 0 Data: (1, 1, 0, 2, 1, 2)
# Pred: 2 Real: 2 Data: (1, 1, 0, 2, 0, 1)
# Pred: 0 Real: 0 Data: (3, 2, 3, 2, 0, 2)
# Pred: 2 Real: 2 Data: (0, 0, 2, 0, 2, 2)
# Pred: 2 Real: 2 Data: (3, 3, 2, 1, 1, 2)
# Pred: 2 Real: 2 Data: (3, 3, 3, 1, 1, 2)
# Pred: 2 Real: 2 Data: (1, 1, 1, 1, 2, 1)
# Pred: 2 Real: 2 Data: (0, 3, 3, 0, 1, 0)
# Pred: 2 Real: 2 Data: (2, 1, 2, 0, 1, 0)
# Pred: 2 Real: 2 Data: (2, 1, 2, 2, 2, 1)
# Pred: 3 Real: 3 Data: (1, 0, 2, 2, 0, 0)
# Pred: 0 Real: 0 Data: (3, 2, 2, 2, 0, 2)
# Pred: 0 Real: 0 Data: (0, 1, 1, 1, 1, 0)
# Pred: 2 Real: 2 Data: (2, 1, 2, 0, 2, 1)
# Pred: 0 Real: 0 Data: (3, 2, 0, 2, 1, 0)
