# %% [markdown]
# [texto del enlace](https://)##### Copyright 2019 The TensorFlow Authors.

# %%
#@title Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
# https://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.

# %% [markdown]
# #Tensorflow para princiantes

# %% [markdown]
# Download and install the TensorFlow 2.0 Beta package. Import TensorFlow into your program:

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# Install TensorFlow
#!pip install tensorflow==2.0.0-beta1

import tensorflow as tf

# %%
print(tf.__version__)

# %% [markdown]
# Load and prepare the [MNIST dataset](http://yann.lecun.com/exdb/mnist/). Convert the samples from integers to floating-point numbers:

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
#x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.axis("off")

def show_example(row):
  print(y_train[row])
  plt.imshow(x_train[row,:,:], interpolation="nearest",cmap='gray')
  plt.show()
  
unique_y = np.unique(y_train) 
print(unique_y)
show_example(0)

# %%
plt.hist(x_train[0,:,:])
plt.show()

# %% [markdown]
# Build the `tf.keras.Sequential` model by stacking layers. Choose an optimizer and loss function for training:

# %%
from keras.layers import Dense, Conv2D, Flatten
from keras.models import *

def neural_net():
  model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
  ])
  return model

def conv_net():
  model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, kernel_size=3, activation='relu',input_shape=(28,28,1)),
    tf.keras.layers.Conv2D(32, kernel_size=3, activation='relu'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
  ])
  return model

model=neural_net()
model.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

# %% [markdown]
# Train and evaluate the model:

# %%
x_train = x_train.reshape(60000,28,28,1)
x_test = x_test.reshape(10000,28,28,1)
model.fit(x_train, y_train, epochs=5)

model.evaluate(x_test, y_test)

# %%
model.summary()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
y_pred_naive = gnb.fit(x_train.reshape((-1,784)), y_train).predict(x_test.reshape((-1,784)))

# %%
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels

# %%
plot_confusion_matrix(y_test,y_pred_naive,classes=unique_y)

# %%
plot_confusion_matrix(y_test,y_pred_naive,classes=unique_y)

# %% [markdown]
# The image classifier is now trained to ~98% accuracy on this dataset. To learn more, read the [TensorFlow tutorials](https://www.tensorflow.org/beta/tutorials/).
