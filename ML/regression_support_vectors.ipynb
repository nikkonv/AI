# %% [markdown]
# Individualizar el hiperplano, maximizando el margen, teniendo en cuenta que se tolera parte del error
# ![texto alternativo](https://www.researchgate.net/profile/Frank_Boeckler/publication/248396465/figure/fig12/AS:669695405461539@1536679235653/Support-vector-regression-SVR-Illustration-of-an-SVR-regression-function-represented.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

boston = datasets.load_boston()
boston.data.shape
# Out:
# (506, 13)

# %%
print("columnas: ", boston.feature_names)
# Out:
# columnas:  ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
X_svr = boston.data[:, np.newaxis, 5]
y_svr = boston.target

plt.scatter(X_svr, y_svr)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_svr, y_svr, test_size=0.2)

from sklearn.svm import SVR

# algoritmo, kernel: linear, poly, sigmoid
svr = SVR(kernel='poly', C=1.0, epsilon=0.2)

# entrenamiento
svr.fit(X_train, y_train)

Y_pred = svr.predict(X_test)

plt.scatter(X_test, y_test)
plt.plot(X_test, Y_pred, color='red', linewidth=2)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
print("precision: ", svr.score(X_train, y_train))

### in this case kernel poly is better than kernel linear, poly gets more score
# Out:
# precision:  0.5564491478238515
